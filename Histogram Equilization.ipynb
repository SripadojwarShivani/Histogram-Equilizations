# %%
import cv2

# %%
#reading an image
img=cv2.imread("/home/shivanisri/Downloads/light.jpeg")
#displaying ima
cv2.imshow("before",img)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
equalized = cv2.equalizeHist(gray)
cv2.imshow("Result",equalized)
cv2.waitKey(0)
# Out:
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# QObject::moveToThread: Current thread (0x559c69baec80) is not the object's thread (0x559c69bb4670).
# Cannot move to target thread (0x559c69baec80)
#
# ...
